# %% [markdown]
# **Problem Statement:**
#
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
#
# **Data Set used :-** #https://www.kaggle.com/datasets/thedevastator/analyzing-credit-card-spending-habits-in-india/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data from CSV file
df = pd.read_csv('Credit card transactions - India - Simple.csv')
df
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
df.head(4000)
# Out:
#       index                   City       Date  Card Type Exp Type Gender  \
# 0         0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1         1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2         2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3         3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4         4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...     ...                    ...        ...        ...      ...    ...
# 3995   3995           Delhi, India  13-Nov-13       Gold     Food      M
# 3996   3996       Ahmedabad, India   9-Jun-14       Gold    Bills      F
# 3997   3997           Delhi, India   3-Jun-14   Platinum     Fuel      M
# 3998   3998       Ahmedabad, India   7-Apr-15     Silver     Food      F
# 3999   3999  Greater Mumbai, India  18-Mar-15  Signature     Fuel      F
#
#       Amount
# 0      82475
# 1      32555
# 2     101738
# 3     123424
# 4     171574
# ...

# %%
# Bar chart for the distribution of a categorical variable (gender)
plt.figure(figsize=(6, 5))
sns.set(style="whitegrid")
sns.countplot(x='Gender', data=df.count, palette='dark')
plt.title('Distribution of Gender in the Top 4000 Rows')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the dataset we can say that Female has more Credit card transactions compare to male
